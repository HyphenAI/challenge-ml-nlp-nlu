# %%
from challenge_solution import training_model

# %%
model , df = training_model.train_using_bag_word_model('training_dataset_2.txt' , 'test-data.txt')
# Out:
# CLASSIFICATION_REPORT :
#               precision    recall  f1-score   support
#
#          -1       0.00      0.00      0.00         1
#           0       1.00      1.00      1.00         3
#           1       1.00      1.00      1.00         2
#           2       0.40      0.67      0.50         3
#           3       1.00      1.00      1.00         3
#           4       0.75      1.00      0.86         3
#           5       1.00      1.00      1.00         2
#           6       1.00      1.00      1.00         2
#           7       1.00      1.00      1.00         2
#           8       1.00      1.00      1.00         4
#           9       1.00      1.00      1.00         3
#          10       1.00      0.12      0.22         8
#          11       0.00      0.00      0.00         1
#          12       1.00      1.00      1.00         2
#          13       1.00      1.00      1.00         3
#          14       0.00      0.00      0.00         1
# ...

# %%
df
# Out:
#                                              question                                      actual_answer                                   predicted_answer
# 0                             How can we book a room?  Hello, you can book online on hyphen.ai, on ou...  Hello, you can book online on hyphen.ai, on ou...
# 1                               I want to book a room  Hello, you can book online on hyphen.ai, on ou...  Hello, you can book online on hyphen.ai, on ou...
# 2                               i need to book a room  Hello, you can book online on hyphen.ai, on ou...  Hello, you can book online on hyphen.ai, on ou...
# 3                   What is the Best price Guarantee?  Hello,  we guarantee that the prices offered o...  Hello,  we guarantee that the prices offered o...
# 4                 what is your best price guarantee ?  Hello,  we guarantee that the prices offered o...  Hello,  we guarantee that the prices offered o...
# ...

# %%
model , df =  training_model.train_using_bag_word_model('training_dataset.txt' , 'test_dataset.txt')
# Out:
# CLASSIFICATION_REPORT :
#               precision    recall  f1-score   support
#
#          -1       0.00      0.00      0.00         2
#           1       1.00      1.00      1.00         1
#           2       1.00      1.00      1.00         1
#           3       0.67      1.00      0.80         2
#           4       1.00      1.00      1.00         1
#           5       1.00      1.00      1.00         1
#           6       0.00      0.00      0.00         1
#           7       1.00      1.00      1.00         1
#           8       0.75      1.00      0.86         3
#           9       1.00      1.00      1.00         1
#          10       1.00      1.00      1.00         1
#          11       1.00      1.00      1.00         2
#          12       1.00      1.00      1.00         2
#          13       1.00      1.00      1.00         1
#          14       0.25      1.00      0.40         1
#          15       1.00      1.00      1.00         1
# ...

# %%
df
# Out:
#                                              question                                      actual_answer                                   predicted_answer
# 0                                                 hey                                                 hi                                                 hi
# 1                                           what's up                                       nothing much                                       nothing much
# 2                                           greetings                                          greetings                                          greetings
# 3                                         how are you                                     I'm doing good                                     I'm doing good
# 4                             how are you doing today                                     I'm doing good                                     I'm doing good
# ...
